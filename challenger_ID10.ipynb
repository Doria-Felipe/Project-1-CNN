# %% [markdown]
# # Task
#
# #### Build a Convolutional Neural Network (CNN) model to classify images from a given dataset into predefined categories/classes.

# %% [markdown]
# ## The Dataset
#
# #### We could choose between Animals 10 and CIFAR-10; we chose the latter to focus on training our models.
#
# #### - 60,000 32x32 color images in 10 classes
# #### - 6,000 images per class.

# %% [markdown]
# ## Imports

# %%
import os
import pickle
import random
import zipfile
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import SGD, Adam, Adagrad
from tensorflow.keras.metrics import TopKCategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory, to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Activation, RandomFlip, RandomTranslation, Lambda

# %% [markdown]
# ## Setting the random seed
#
# #### This will guarantee near-reproducible results.
#
# #### TensorFlow is not bit-exact deterministic by default, so some tiny numerical differences can occur (~0.1 %-0.3 %).
#
# #### This can escalate exponentially, but the cost for determinism would be slowing down our training using the following import:
#
# #### `from tensorflow.config.experimental import enable_op_determinism`
#
# #### We decided not to use the import.

# %%
seed = 42
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Load CIFAR-10 dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Data Exploration
#
# #### Let's take a look at the shapes of our training and testing data.
#
# #### The second, third, and fourth columns of X will be our input format for the NN.

# %%
print('X_train: ' ,X_train.shape)
print('X_test: ' ,X_test.shape)
print('y_train: ' ,y_train.shape)
print('y_test: ' ,y_test.shape)
# Out:
# X_train:  (50000, 32, 32, 3)
# X_test:  (10000, 32, 32, 3)
# y_train:  (50000, 1)
# y_test:  (10000, 1)

# %% [markdown]
# #### Also, it is good to define our classes as they are presented on the dataset homepage.
#
# #### As we can see below, they are all perfectly balanced.

# %%
class_names = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(class_names[u], c)
# Out:
# airplane 5000
# automobile 5000
# bird 5000
# cat 5000
# deer 5000
# dog 5000
# frog 5000
# horse 5000
# ship 5000
# truck 5000

# %% [markdown]
# ### Check the min max pixel value
#
# #### Just as a sanity check, let's see the min and max of the values, they should be 0 and 255

# %%
print("Min pixel value:", X_train.min())
print("Max pixel value:", X_train.max())
# Out:
# Min pixel value: 0
# Max pixel value: 255

# %% [markdown]
# ## Data Preprocessing
#
# #### Let's make our target y categorical and normalize our X by dividing its value by 255.

# %% [markdown]
# ### OHE y to categorical

# %%
num_classes = 10
y_train_ohe = to_categorical(y_train, num_classes)
y_test_ohe  = to_categorical(y_test,  num_classes)

# %%
print('y_train_ohe: ' ,y_train_ohe.shape)
print('y_test_ohe: ' ,y_test_ohe.shape)
# Out:
# y_train_ohe:  (50000, 10)
# y_test_ohe:  (10000, 10)

# %% [markdown]
# ### Normalize the training and test

# %%
X_train = X_train.astype('float32')/255.0

# %%
X_test = X_test.astype('float32')/255.0

# %% [markdown]
# #### As a sanity check let's see the mean and standard deviation.

# %%
mean_train = X_train.mean(axis=(0,1,2))
std_train  = X_train.std(axis=(0,1,2))

mean_test = X_test.mean(axis=(0,1,2))
std_test  = X_test.std(axis=(0,1,2))


print("Mean:", mean_train)
print("Std:", std_train)
print("Mean:", mean_test)
print("Std:", std_test)
# Out:
# Mean: [0.4914009  0.48215896 0.4465308 ]
# Std: [0.24703279 0.24348423 0.26158753]
# Mean: [0.49421427 0.4851322  0.45040992]
# Std: [0.24665268 0.24289216 0.2615922 ]

# %%
challenger = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
challenger_history = challenger.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 26s 61ms/step - accuracy: 0.2978 - loss: 1.9229 - val_accuracy: 0.5228 - val_loss: 1.3554
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.4749 - loss: 1.4490 - val_accuracy: 0.5716 - val_loss: 1.2088
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.5288 - loss: 1.3086 - val_accuracy: 0.6126 - val_loss: 1.1211
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.5634 - loss: 1.2190 - val_accuracy: 0.6360 - val_loss: 1.0480
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5924 - loss: 1.1456 - val_accuracy: 0.6562 - val_loss: 0.9991
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.6106 - loss: 1.0985 - val_accuracy: 0.6590 - val_loss: 0.9767
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.6192 - loss: 1.0583 - val_accuracy: 0.6606 - val_loss: 0.9721
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.6389 - loss: 1.0148 - val_accuracy: 0.6570 - val_loss: 0.9716
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.6463 - loss: 0.9889 - val_accuracy: 0.6730 - val_loss: 0.9325
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.6547 - loss: 0.9583 - val_accuracy: 0.6696 - val_loss: 0.9460
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.6641 - loss: 0.9420 - val_accuracy: 0.6824 - val_loss: 0.9105
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.6731 - loss: 0.9109 - val_accuracy: 0.6786 - val_loss: 0.9234
# Epoch 13/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.6793 - loss: 0.8977 - val_accuracy: 0.6858 - val_loss: 0.9054
# Epoch 14/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.6880 - loss: 0.8655 - val_accuracy: 0.6896 - val_loss: 0.9069
# Epoch 15/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.6955 - loss: 0.8406 - val_accuracy: 0.6834 - val_loss: 0.9282
# Epoch 16/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.6982 - loss: 0.8328 - val_accuracy: 0.6856 - val_loss: 0.9289
# Epoch 17/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.7001 - loss: 0.8217 - val_accuracy: 0.6972 - val_loss: 0.8836
# Epoch 18/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 25s 69ms/step - accuracy: 0.7077 - loss: 0.8058 - val_accuracy: 0.6952 - val_loss: 0.8882
# Epoch 19/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 22s 63ms/step - accuracy: 0.7176 - loss: 0.7807 - val_accuracy: 0.6952 - val_loss: 0.8888
# Epoch 20/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 24s 67ms/step - accuracy: 0.7174 - loss: 0.7740 - val_accuracy: 0.6916 - val_loss: 0.9246
# Epoch 21/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.7245 - loss: 0.7546 - val_accuracy: 0.6940 - val_loss: 0.9119
# Epoch 22/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.7325 - loss: 0.7334 - val_accuracy: 0.7014 - val_loss: 0.9036

# %% [markdown]
# #### We got 68 % as Test accuracy and 0.91 as test loss.

# %%
test_loss, test_acc = challenger.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

plt.figure(figsize=(8, 5))
plt.plot(challenger_history.history['loss'], label='Training Loss')
plt.plot(challenger_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6923 - loss: 0.8869
# Test accuracy: 0.6866999864578247
# Test loss: 0.9126209020614624

# %%
y_pred_proba = challenger.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# with open('challenger1.pkl', 'wb') as file:
#     pickle.dump(challenger, file)

# %%
challenger2 = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), activation="relu"),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger2.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
challenger2_history = challenger2.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 37s 85ms/step - accuracy: 0.1756 - loss: 2.1255 - val_accuracy: 0.3542 - val_loss: 1.6817
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - accuracy: 0.3319 - loss: 1.7419 - val_accuracy: 0.4354 - val_loss: 1.5227
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.4163 - loss: 1.5761 - val_accuracy: 0.4746 - val_loss: 1.3991
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.4656 - loss: 1.4550 - val_accuracy: 0.5170 - val_loss: 1.3204
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step - accuracy: 0.4957 - loss: 1.3806 - val_accuracy: 0.5310 - val_loss: 1.2535
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 78ms/step - accuracy: 0.5152 - loss: 1.3230 - val_accuracy: 0.5582 - val_loss: 1.1925
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.5432 - loss: 1.2679 - val_accuracy: 0.5900 - val_loss: 1.1330
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.5578 - loss: 1.2269 - val_accuracy: 0.6018 - val_loss: 1.0899
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.5741 - loss: 1.1873 - val_accuracy: 0.6050 - val_loss: 1.0746
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 25s 70ms/step - accuracy: 0.5886 - loss: 1.1491 - val_accuracy: 0.6194 - val_loss: 1.0539
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 49s 139ms/step - accuracy: 0.5945 - loss: 1.1275 - val_accuracy: 0.6386 - val_loss: 1.0083
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 63s 179ms/step - accuracy: 0.6093 - loss: 1.0883 - val_accuracy: 0.6364 - val_loss: 1.0067
# Epoch 13/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 64s 181ms/step - accuracy: 0.6206 - loss: 1.0714 - val_accuracy: 0.6466 - val_loss: 0.9843
# Epoch 14/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 63s 179ms/step - accuracy: 0.6242 - loss: 1.0558 - val_accuracy: 0.6516 - val_loss: 0.9587
# Epoch 15/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 66s 187ms/step - accuracy: 0.6306 - loss: 1.0389 - val_accuracy: 0.6568 - val_loss: 0.9573
# Epoch 16/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━
50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 47s 80ms/step - accuracy: 0.7339 - loss: 0.7660 - val_accuracy: 0.7358 - val_loss: 0.7490
# Epoch 43/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.7327 - loss: 0.7634 - val_accuracy: 0.7392 - val_loss: 0.7474
# Epoch 44/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 27s 76ms/step - accuracy: 0.7340 - loss: 0.7554 - val_accuracy: 0.7424 - val_loss: 0.7213
# Epoch 45/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 86s 243ms/step - accuracy: 0.7369 - loss: 0.7550 - val_accuracy: 0.7508 - val_loss: 0.7154
# Epoch 46/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.7412 - loss: 0.7431 - val_accuracy: 0.7458 - val_loss: 0.7220
# Epoch 47/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 27s 77ms/step - accuracy: 0.7358 - loss: 0.7525 - val_accuracy: 0.7460 - val_loss: 0.7243
# Epoch 48/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 33s 93ms/step - accuracy: 0.7400 - loss: 0.7430 - val_accuracy: 0.7482 - val_loss: 0.7206
# Epoch 49/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 63s 178ms/step - accuracy: 0.7470 - loss: 0.7316 - val_accuracy: 0.7402 - val_loss: 0.7368
# Epoch 50/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.7404 - loss: 0.7387 - val_accuracy: 0.7504 - val_loss: 0.7111

# %%
challenger2.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 28, 28, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 10, 10, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 5, 5, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 5, 5, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 128)                 │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 157,856 (616.63 KB)
#  Trainable params: 52,618 (205.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 105,238 (411.09 KB)

# %% [markdown]
# #### We got 74 % as Test accuracy and 0.73 as test loss.

# %%
test_loss, test_acc = challenger2.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

plt.figure(figsize=(8, 5))
plt.plot(challenger2_history.history['loss'], label='Training Loss')
plt.plot(challenger2_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.7494 - loss: 0.7274
# Test accuracy: 0.7465999722480774
# Test loss: 0.7314639091491699

# %%
y_pred_proba = challenger2.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# with open('challenger2.pkl', 'wb') as file:
#     pickle.dump(challenger2, file)

# %%
challenger3 = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger3.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
challenger3_history = challenger3.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 93s 242ms/step - accuracy: 0.1921 - loss: 2.1114 - val_accuracy: 0.3684 - val_loss: 1.6450
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 75s 214ms/step - accuracy: 0.3417 - loss: 1.7016 - val_accuracy: 0.4204 - val_loss: 1.5264
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 60s 169ms/step - accuracy: 0.3991 - loss: 1.5764 - val_accuracy: 0.4628 - val_loss: 1.4438
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 58s 164ms/step - accuracy: 0.4513 - loss: 1.4806 - val_accuracy: 0.5040 - val_loss: 1.3452
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 71s 200ms/step - accuracy: 0.4869 - loss: 1.3940 - val_accuracy: 0.5344 - val_loss: 1.2905
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━
is=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# with open('challenger3.pkl', 'wb') as file:
#     pickle.dump(challenger3, file)

# %% [markdown]
# ## Challenger Model 4:
#
# #### Added TopKAccuracy as a metric with K=3, which increases the likelihood of correct classification.
#
# #### Even if the model is incorrect, the chances of being in the top 3 accurate predictions are higher.
#
# #### We got 77 % as Test accuracy and 0.66 as test loss.

# %%
challenger4 = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger4.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
challenger4_history = challenger4.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 43s 90ms/step - accuracy: 0.1892 - loss: 2.1057 - top3_accuracy: 0.4879 - val_accuracy: 0.3736 - val_loss: 1.6480 - val_top3_accuracy: 0.7454
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - accuracy: 0.3511 - loss: 1.6891 - top3_accuracy: 0.7273 - val_accuracy: 0.4310 - val_loss: 1.5063 - val_top3_accuracy: 0.7960
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - accuracy: 0.4139 - loss: 1.5616 - top3_accuracy: 0.7728 - val_accuracy: 0.4766 - val_loss: 1.4156 - val_top3_accuracy: 0.8160
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - accuracy: 0.4537 - loss: 1.4733 - top3_accuracy: 0.7973 - val_accuracy: 0.5154 - val_loss: 1.3333 - val_top3_accuracy: 0.8320
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 82ms/step - accuracy: 0.4908 - loss: 1.3838 - top3_accuracy: 0.8260 - val_accuracy: 0.5272 - val_loss: 1.2945 - val_top3_accuracy: 0.8402
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 29s 83ms/step - accuracy: 0.5197 - loss: 1.3210 - top3_accuracy: 0.8387 - val_accuracy: 0.5552 - val_loss: 1.2116 - val_top3_accuracy: 0.8632
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 43s 121ms/step - accuracy: 0.5400 - loss: 1.2643 - top3_accuracy: 0.8493 - val_accuracy: 0.5776 - val_loss: 1.1662 - val_top3_accuracy: 0.8696
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 52s 147ms/step - accuracy: 0.5618 - loss: 1.2156 - top3_accuracy: 0.8620 - val_accuracy: 0.5792 - val_loss: 1.1403 - val_top3_accuracy: 0.8782
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.5757 - loss: 1.1708 - top3_accuracy: 0.8706 - val_accuracy: 0.6080 - val_loss: 1.0765 - val_top3_accuracy: 0.8904
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 25s 71ms/step - accuracy: 0.5928 - loss: 1.1389 - top3_accuracy: 0.8760 - val_accuracy: 0.6218 - val_loss: 1.0502 - val_top3_accuracy: 0.8962
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 53s 152ms/step - accuracy: 0.6011 - loss: 1.1056 - top3_accuracy: 0.8808 - val_accuracy: 0.6272 - val_loss: 1.0363 - val_top3_accuracy: 0.8992
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━
50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 82s 233ms/step - accuracy: 0.7583 - loss: 0.6836 - top3_accuracy: 0.9478 - val_accuracy: 0.7680 - val_loss: 0.6479 - val_top3_accuracy: 0.9538
# Epoch 44/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 106s 301ms/step - accuracy: 0.7662 - loss: 0.6690 - top3_accuracy: 0.9490 - val_accuracy: 0.7754 - val_loss: 0.6253 - val_top3_accuracy: 0.9580
# Epoch 46/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 85s 242ms/step - accuracy: 0.7672 - loss: 0.6550 - top3_accuracy: 0.9538 - val_accuracy: 0.7816 - val_loss: 0.6209 - val_top3_accuracy: 0.9572
# Epoch 50/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 82s 233ms/step - accuracy: 0.7744 - loss: 0.6441 - top3_accuracy: 0.9525 - val_accuracy: 0.7752 - val_loss: 0.6249 - val_top3_accuracy: 0.9584

# %%
challenger4.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_44 (Conv2D)                   │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_45 (Conv2D)                   │ (None, 28, 28, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_46 (Conv2D)                   │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_47 (Conv2D)                   │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_24 (MaxPooling2D)      │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_32 (Dropout)                 │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_7           │ (None, 64)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_33 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 225,536 (881.00 KB)
#  Trainable params: 75,178 (293.66 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 150,358 (587.34 KB)

# %% [markdown]
# #### We got 77 % as Test accuracy and 0.66 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger4.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

plt.figure(figsize=(8, 5))
plt.plot(challenger4_history.history['loss'], label='Training Loss')
plt.plot(challenger4_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7715 - loss: 0.6599 - top3_accuracy: 0.9499
# Test accuracy: 0.7692999839782715
# Test loss: 0.6625622510910034

# %%
y_pred_proba = challenger4.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
challenger6 = Sequential([
    Conv2D(64, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger6.compile(
    optimizer=SGD(learning_rate=0.05
                  ,momentum=0.9
                  ,nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
challenger6_history = challenger6.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=512,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 92s 989ms/step - accuracy: 0.1248 - loss: 2.2845 - top3_accuracy: 0.3549 - val_accuracy: 0.0980 - val_loss: 2.2961 - val_top3_accuracy: 0.3210
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 941ms/step - accuracy: 0.1241 - loss: 2.2758 - top3_accuracy: 0.3577 - val_accuracy: 0.1742 - val_loss: 2.2297 - val_top3_accuracy: 0.4592
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 932ms/step - accuracy: 0.1675 - loss: 2.1936 - top3_accuracy: 0.4597 - val_accuracy: 0.2204 - val_loss: 2.0540 - val_top3_accuracy: 0.5534
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 963ms/step - accuracy: 0.2101 - loss: 2.0807 - top3_accuracy: 0.5344 - val_accuracy: 0.2358 - val_loss: 2.0037 - val_top3_accuracy: 0.5946
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s
(1.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 277,964 (1.06 MB)

# %% [markdown]
# #### We got 77 % as Test accuracy and 0.65 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger6.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)

plt.figure(figsize=(8, 5))
plt.plot(challenger6_history.history['loss'], label='Training Loss')
plt.plot(challenger6_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.7790 - loss: 0.6412 - top3_accuracy: 0.9524
# Test accuracy: 0.7759000062942505
# Test loss: 0.6567584872245789

# %%
print("Test Top3 accuracy:", top3_accuracy)
# Out:
# Test Top3 accuracy: 0.9502000212669373

# %%
y_pred_proba = challenger6.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
with open('challenger6.pkl', 'wb') as file:
    pickle.dump(challenger6, file)

# %%
challenger7 = Sequential([
    Conv2D(64, (3,3), padding="same", activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

# %%
challenger7.compile(
    optimizer=SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %% [markdown]
# ### Reduce Ron Plateau

# %%
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=2, min_lr=1e-4
)

# %%
history = challenger7.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=80,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 132s 363ms/step - accuracy: 0.1187 - loss: 2.2938 - top3_accuracy: 0.3343 - val_accuracy: 0.1078 - val_loss: 2.2961 - val_top3_accuracy: 0.3078 - learning_rate: 0.0500
# Epoch 2/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 121s 345ms/step - accuracy: 0.1322 - loss: 2.2710 - top3_accuracy: 0.3631 - val_accuracy: 0.1582 - val_loss: 2.1755 - val_top3_accuracy: 0.4420 - learning_rate: 0.0500
# Epoch 3/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 342ms/step - accuracy: 0.2170 - loss: 2.0357 - top3_accuracy: 0.5631 - val_accuracy: 0.3018 - val_loss: 1.8320 - val_top3_accuracy: 0.6796 - learning_rate: 0.0500
# Epoch 4/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 117s 331ms/step - accuracy: 0.2947 - loss: 1.8409 - top3_accuracy: 0.6676 - val_accuracy: 0.3476 - val_loss: 1.6782 - val_top3_accuracy: 0.7066 - learning_rate: 0.0500
# Epoch 5/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 115s 327ms/step - accuracy: 0.3702 - loss: 1.6780 - top3_accuracy: 0.7364 - val_accuracy: 0.4208 - val_loss: 1.5163 - val_top3_accuracy: 0.7726 - learning_rate: 0.0500
# Epoch 6/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 168s 478ms/step - accuracy: 0.4284 - loss: 1.5171 - top3_accuracy: 0.7843 - val_accuracy: 0.5000 - val_loss: 1.3435 - val_top3_accuracy: 0.8298 - learning_rate: 0.0500
# Epoch 7/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 169s 482ms/step - accuracy: 0.4771 - loss: 1.4040 - top3_accuracy: 0.8181 - val_accuracy: 0.5342 - val_loss: 1.2658 - val_top3_accuracy: 0.8462 - learning_rate: 0.0500
# Epoch 8/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━
80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 140s 397ms/step - accuracy: 0.7654 - loss: 0.6793 - top3_accuracy: 0.9482 - val_accuracy: 0.7832 - val_loss: 0.6474 - val_top3_accuracy: 0.9506 - learning_rate: 0.0250
# Epoch 23/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 138s 392ms/step - accuracy: 0.7821 - loss: 0.6309 - top3_accuracy: 0.9541 - val_accuracy: 0.7844 - val_loss: 0.6237 - val_top3_accuracy: 0.9552 - learning_rate: 0.0250
# Epoch 24/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 115s 328ms/step - accuracy: 0.7871 - loss: 0.6114 - top3_accuracy: 0.9574 - val_accuracy: 0.7718 - val_loss: 0.6779 - val_top3_accuracy: 0.9512 - learning_rate: 0.0250
# Epoch 25/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 334ms/step - accuracy: 0.7885 - loss: 0.6023 - top3_accuracy: 0.9568 - val_accuracy: 0.7824 - val_loss: 0.6336 - val_top3_accuracy: 0.9594 - learning_rate: 0.0250
# Epoch 26/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 140s 397ms/step - accuracy: 0.8038 - loss: 0.5642 - top3_accuracy: 0.9609 - val_accuracy: 0.7958 - val_loss: 0.6053 - val_top3_accuracy: 0.9586 - learning_rate: 0.0125
# Epoch 27/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 148s 421ms/step - accuracy: 0.8106 - loss: 0.5439 - top3_accuracy: 0.9630 - val_accuracy: 0.8000 - val_loss: 0.5930 - val_top3_accuracy: 0.9620 - learning_rate: 0.0125
# Epoch 28/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 135s 383ms/step - accuracy: 0.8140 - loss: 0.5364 - top3_accuracy: 0.9639 - val_accuracy: 0.8028 - val_loss: 0.5953 - val_top3_accuracy: 0.9618 - learning_rate: 0.0125
# Epoch 29/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 141s 402ms/step - accuracy: 0.8204 - loss: 0.5197 - top3_accuracy: 0.9665 - val_accuracy: 0.8026 - val_loss: 0.6062 - val_top3_accuracy: 0.9602 - learning_rate: 0.0125
# Epoch 30/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 147s 415ms/step - accuracy: 0.8262 - loss: 0.5030 - top3_accuracy: 0.9686 - val_accuracy: 0.8048 - val_loss: 0.5813 - val_top3_accuracy: 0.9618 - learning_rate: 0.0063
# Epoch 31/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 126s 359ms/step - accuracy: 0.8303 - loss: 0.4886 - top3_accuracy: 0.9699 - val_accuracy: 0.8076 - val_loss: 0.5788 - val_top3_accuracy: 0.9640 - learning_rate: 0.0063
# Epoch 32/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 132s 376ms/step - accuracy: 0.8321 - loss: 0.4881 - top3_accuracy: 0.9704 - val_accuracy: 0.8086 - val_loss: 0.5784 - val_top3_accuracy: 0.9630 - learning_rate: 0.0063
# Epoch 33/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 132s 374ms/step - accuracy: 0.8318 - loss: 0.4780 - top3_accuracy: 0.9714 - val_accuracy: 0.8064 - val_loss: 0.5719 - val_top3_accuracy: 0.9622 - learning_rate: 0.0063
# Epoch 34/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 135s 384ms/step - accuracy: 0.8346 - loss: 0.4760 - top3_accuracy: 0.9703 - val_accuracy: 0.8102 - val_loss: 0.5691 - val_top3_accuracy: 0.9630 - learning_rate: 0.0063
# Epoch 35/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 138s 392ms/step - accuracy: 0.8400 - loss: 0.4655 - top3_accuracy: 0.9707 - val_accuracy: 0.8108 - val_loss: 0.5739 - val_top3_accuracy: 0.9640 - learning_rate: 0.0063
# Epoch 36/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 141s 400ms/step - accuracy: 0.8404 - loss: 0.4634 - top3_accuracy: 0.9724 - val_accuracy: 0.8088 - val_loss: 0.5735 - val_top3_accuracy: 0.9624 - learning_rate: 0.0063
# Epoch 37/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 140s 397ms/step - accuracy: 0.8414 - loss: 0.4534 - top3_accuracy: 0.9729 - val_accuracy: 0.8110 - val_loss: 0.5705 - val_top3_accuracy: 0.9632 - learning_rate: 0.0031
# Epoch 38/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 145s 412ms/step - accuracy: 0.8434 - loss: 0.4446 - top3_accuracy: 0.9756 - val_accuracy: 0.8158 - val_loss: 0.5635 - val_top3_accuracy: 0.9634 - learning_rate: 0.0031
# Epoch 39/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 174s 495ms/step - accuracy: 0.8459 - loss: 0.4425 - top3_accuracy: 0.9753 - val_accuracy: 0.8150 - val_loss: 0.5658 - val_top3_accuracy: 0.9646 - learning_rate: 0.0031
# Epoch 40/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 152s 431ms/step - accuracy: 0.8473 - loss: 0.4408 - top3_accuracy: 0.9754 - val_accuracy: 0.8144 - val_loss: 0.5703 - val_top3_accuracy: 0.9624 - learning_rate: 0.0031
# Epoch 41/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 154s 438ms/step - accuracy: 0.8487 - loss: 0.4337 - top3_accuracy: 0.9759 - val_accuracy: 0.8134 - val_loss: 0.5650 - val_top3_accuracy: 0.9650 - learning_rate: 0.0016
# Epoch 42/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 165s 469ms/step - accuracy: 0.8506 - loss: 0.4244 - top3_accuracy: 0.9763 - val_accuracy: 0.8176 - val_loss: 0.5599 - val_top3_accuracy: 0.9638 - learning_rate: 0.0016
# Epoch 43/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 152s 433ms/step - accuracy: 0.8514 - loss: 0.4253 - top3_accuracy: 0.9769 - val_accuracy: 0.8124 - val_loss: 0.5593 - val_top3_accuracy: 0.9646 - learning_rate: 0.0016
# Epoch 44/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.8535 - loss: 0.4270 - top3_accuracy: 0.9747 - val_accuracy: 0.8136 - val_loss: 0.5662 - val_top3_accuracy: 0.9646 - learning_rate: 0.0016
# Epoch 45/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 165s 468ms/step - accuracy: 0.8511 - loss: 0.4310 - top3_accuracy: 0.9771 - val_accuracy: 0.8124 - val_loss: 0.5636 - val_top3_accuracy: 0.9642 - learning_rate: 0.0016
# Epoch 46/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 141s 401ms/step - accuracy: 0.8516 - loss: 0.4191 - top3_accuracy: 0.9761 - val_accuracy: 0.8168 - val_loss: 0.5619 - val_top3_accuracy: 0.9644 - learning_rate: 7.8125e-04
# Epoch 47/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 145s 411ms/step - accuracy: 0.8534 - loss: 0.4231 - top3_accuracy: 0.9762 - val_accuracy: 0.8154 - val_loss: 0.5605 - val_top3_accuracy: 0.9658 - learning_rate: 7.8125e-04
# Epoch 48/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 148s 421ms/step - accuracy: 0.8579 - loss: 0.4153 - top3_accuracy: 0.9782 - val_accuracy: 0.8190 - val_loss: 0.5600 - val_top3_accuracy: 0.9648 - learning_rate: 3.9063e-04

# %%
challenger7.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 555,926 (2.12 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 277,964 (1.06 MB)

# %% [markdown]
# #### We got 80 % as Test accuracy and 0.58 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger7.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)

plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.8069 - loss: 0.5856 - top3_accuracy: 0.9601
# Test accuracy: 0.8058000206947327
# Test loss: 0.5828078985214233
# Test Top3 accuracy: 0.9589999914169312

# %%
y_pred_proba = challenger7.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
with open('challenger7.pkl', 'wb') as file:
    pickle.dump(challenger7, file)

# %%
challenger8 = Sequential([
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),

    Conv2D(64, (3,3), padding="same", activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger8.compile(
    optimizer=SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
challenger8_history = challenger8.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=80,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 149s 404ms/step - accuracy: 0.1631 - loss: 2.1996 - top3_accuracy: 0.4325 - val_accuracy: 0.2650 - val_loss: 1.9134 - val_top3_accuracy: 0.6372 - learning_rate: 0.0500
# Epoch 2/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 155s 439ms/step - accuracy: 0.2665 - loss: 1.8980 - top3_accuracy: 0.6420 - val_accuracy: 0.3862 - val_loss: 1.6068 - val_top3_accuracy: 0.7498 - learning_rate: 0.0500
# Epoch 3/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.3667 - loss: 1.6681 - top3_accuracy: 0.7401 - val_accuracy: 0.4308 - val_loss: 1.4990 - val_top3_accuracy: 0.7866 - learning_rate: 0.0500
# Epoch 4/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 150s 425ms/step - accuracy: 0.4260 - loss: 1.5232 - top3_accuracy: 0.7879 - val_accuracy: 0.5090 - val_loss: 1.3559 - val_top3_accuracy: 0.8344 - learning_rate: 0.0500
# Epoch 5/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 152s 431ms/step - accuracy: 0.4775 - loss: 1.4077 - top3_accuracy: 0.8216 - val_accuracy: 0.5460 - val_loss: 1.2161 - val_top3_accuracy: 0.8540 - learning_rate: 0.0500
# Epoch 6/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 149s 422ms/step - accuracy: 0.5189 - loss: 1.3084 - top3_accuracy: 0.8413 - val_accuracy: 0.5970 - val_loss: 1.1022 - val_top3_accuracy: 0.8870 - learning_rate: 0.0500
# Epoch 7/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 151s 428ms/step - accuracy: 0.5591 - loss: 1.2273 - top3_accuracy: 0.8578 - val_accuracy: 0.6140 - val_loss: 1.0486 - val_top3_accuracy: 0.8976 - learning_rate: 0.0500
# Epoch 8/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 159s 451ms/step - accuracy: 0.5776 - loss: 1.1689 - top3_accuracy: 0.8707 - val_accuracy: 0.6442 - val_loss: 0.9786 - val_top3_accuracy: 0.9084 - learning_rate: 0.0500
# Epoch 9/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━
80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 122s 348ms/step - accuracy: 0.7521 - loss: 0.7226 - top3_accuracy: 0.9416 - val_accuracy: 0.7814 - val_loss: 0.6256 - val_top3_accuracy: 0.9528 - learning_rate: 0.0500
# Epoch 25/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.7579 - loss: 0.7020 - top3_accuracy: 0.9435 - val_accuracy: 0.7852 - val_loss: 0.6016 - val_top3_accuracy: 0.9606 - learning_rate: 0.0500
# Epoch 26/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 341ms/step - accuracy: 0.7601 - loss: 0.6914 - top3_accuracy: 0.9463 - val_accuracy: 0.7850 - val_loss: 0.6317 - val_top3_accuracy: 0.9548 - learning_rate: 0.0500
# Epoch 27/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 112s 318ms/step - accuracy: 0.7612 - loss: 0.6935 - top3_accuracy: 0.9437 - val_accuracy: 0.7808 - val_loss: 0.6230 - val_top3_accuracy: 0.9552 - learning_rate: 0.0500
# Epoch 28/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 112s 317ms/step - accuracy: 0.7785 - loss: 0.6432 - top3_accuracy: 0.9512 - val_accuracy: 0.7994 - val_loss: 0.5639 - val_top3_accuracy: 0.9598 - learning_rate: 0.0250
# Epoch 29/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 337ms/step - accuracy: 0.7913 - loss: 0.6073 - top3_accuracy: 0.9558 - val_accuracy: 0.8042 - val_loss: 0.5636 - val_top3_accuracy: 0.9622 - learning_rate: 0.0250
# Epoch 30/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 340ms/step - accuracy: 0.7934 - loss: 0.6040 - top3_accuracy: 0.9561 - val_accuracy: 0.8040 - val_loss: 0.5588 - val_top3_accuracy: 0.9632 - learning_rate: 0.0250
# Epoch 31/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.7984 - loss: 0.5964 - top3_accuracy: 0.9560 - val_accuracy: 0.8072 - val_loss: 0.5558 - val_top3_accuracy: 0.9642 - learning_rate: 0.0250
# Epoch 32/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.7994 - loss: 0.5840 - top3_accuracy: 0.9586 - val_accuracy: 0.8118 - val_loss: 0.5382 - val_top3_accuracy: 0.9660 - learning_rate: 0.0250
# Epoch 33/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 126s 356ms/step - accuracy: 0.8023 - loss: 0.5829 - top3_accuracy: 0.9579 - val_accuracy: 0.8054 - val_loss: 0.5550 - val_top3_accuracy: 0.9632 - learning_rate: 0.0250
# Epoch 34/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8065 - loss: 0.5665 - top3_accuracy: 0.9605 - val_accuracy: 0.8162 - val_loss: 0.5312 - val_top3_accuracy: 0.9638 - learning_rate: 0.0250
# Epoch 35/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8034 - loss: 0.5723 - top3_accuracy: 0.9598 - val_accuracy: 0.8104 - val_loss: 0.5470 - val_top3_accuracy: 0.9666 - learning_rate: 0.0250
# Epoch 36/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.8096 - loss: 0.5584 - top3_accuracy: 0.9602 - val_accuracy: 0.8174 - val_loss: 0.5328 - val_top3_accuracy: 0.9650 - learning_rate: 0.0250
# Epoch 37/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 339ms/step - accuracy: 0.8150 - loss: 0.5410 - top3_accuracy: 0.9622 - val_accuracy: 0.8316 - val_loss: 0.4864 - val_top3_accuracy: 0.9704 - learning_rate: 0.0125
# Epoch 38/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s
80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 136s 385ms/step - accuracy: 0.8379 - loss: 0.4751 - top3_accuracy: 0.9695 - val_accuracy: 0.8442 - val_loss: 0.4642 - val_top3_accuracy: 0.9716 - learning_rate: 0.0016
# Epoch 52/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 145s 413ms/step - accuracy: 0.8378 - loss: 0.4702 - top3_accuracy: 0.9708 - val_accuracy: 0.8404 - val_loss: 0.4669 - val_top3_accuracy: 0.9708 - learning_rate: 0.0016
# Epoch 53/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 153s 436ms/step - accuracy: 0.8422 - loss: 0.4633 - top3_accuracy: 0.9704 - val_accuracy: 0.8418 - val_loss: 0.4689 - val_top3_accuracy: 0.9718 - learning_rate: 7.8125e-04
# Epoch 54/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 153s 435ms/step - accuracy: 0.8412 - loss: 0.4628 - top3_accuracy: 0.9712 - val_accuracy: 0.8426 - val_loss: 0.4664 - val_top3_accuracy: 0.9716 - learning_rate: 7.8125e-04
# Epoch 55/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.8417 - loss: 0.4576 - top3_accuracy: 0.9715 - val_accuracy: 0.8418 - val_loss: 0.4678 - val_top3_accuracy: 0.9716 - learning_rate: 3.9063e-04

# %%
challenger8.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip_2 (RandomFlip)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_2                 │ (None, 32, 32, 3)           │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 555,926 (2.12 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 277,964 (1.06 MB)

# %% [markdown]
# #### We got 84 % as Test accuracy and 0.47 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger8.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)

plt.figure(figsize=(8, 5))
plt.plot(challenger8_history.history['loss'], label='Training Loss')
plt.plot(challenger8_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.8426 - loss: 0.4780 - top3_accuracy: 0.9696
# Test accuracy: 0.8431000113487244
# Test loss: 0.4781797230243683
# Test Top3 accuracy: 0.9702000021934509

# %%
y_pred_proba = challenger8.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving in pickle

# %%
# with open('challenger8.pkl', 'wb') as file:
#     pickle.dump(challenger8, file)

# %% [markdown]
# ### Loading pickle

# %%
p = Path("challenger8.pkl")
data = p.read_bytes()


idx = data.find(b"PK\x03\x04")
print("ZIP header index:", idx)

if idx != -1:
    out = Path("recovered_challenger8.keras")
    out.write_bytes(data[idx:])
    print("Wrote:", out, "size MB:", out.stat().st_size / (1024*1024))

    # Verify zip integrity
    with zipfile.ZipFile(out, "r") as z:
        print("Zip OK. First entries:", z.namelist()[:20])
else:
    print("No embedded zip header found inside the pickle.")
# Out:
# ZIP header index: 127
# Wrote: recovered_challenger8.keras size MB: 2.173375129699707
# Zip OK. First entries: ['metadata.json', 'config.json', 'model.weights.h5']

# %%
keras_zip = "recovered_challenger8.keras"
with zipfile.ZipFile(keras_zip, "r") as z:
    names = z.namelist()
    h5s = [n for n in names if n.endswith(".h5")]
    print("H5 files:", h5s)

    weight_candidates = [n for n in h5s if "weights" in n.lower()]
    if not weight_candidates:
        weight_candidates = h5s

    weights_name = weight_candidates[0]
    z.extract(weights_name, ".")
    print("Extracted:", weights_name)
# Out:
# H5 files: ['model.weights.h5']
# Extracted: model.weights.h5

# %%
challenger8_fixed = Sequential([
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),

    Conv2D(64, (3,3), padding="same", activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

# %%
dummy = tf.zeros((1, 32, 32, 3), dtype=tf.float32)
_ = challenger8_fixed(dummy, training=False)

challenger8_fixed.load_weights(weights_name)

# %%
challenger8_fixed.save("challenger8_fixed.keras")

# %% [markdown]
# ### Loading keras best model

# %%
m = load_model("challenger8_fixed.keras")

# %%
m.compile(
    optimizer=SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
m.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)           │ (1, 32, 32, 3)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_1                 │ (1, 32, 32, 3)              │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (1, 32, 32, 64)             │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (1, 32, 32, 64)             │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (1, 16, 16, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (1, 16, 16, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (1, 16, 16, 128)            │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (1, 16, 16, 128)            │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (1, 8, 8, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (1, 8, 8, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (1, 128)                    │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (1, 128)                    │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (1, 128)                    │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (1, 10)                     │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 277,962 (1.06 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
test_loss, test_acc, top3_accuracy = m.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8426 - loss: 0.4780 - top3_accuracy: 0.9696
# Test accuracy: 0.8431000113487244
# Test loss: 0.4781797230243683
# Test Top3 accuracy: 0.9702000021934509

# %% [markdown]
# ### Loading the Data Set Again and Using the Preprocessing Libraries of the VGG19
#
# #### The VGG19 has its own library to preprocess its data. It does not use the division by 255.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

y_train_ohe = to_categorical(y_train, 10)
y_test_ohe  = to_categorical(y_test, 10)

X_train_pp = preprocess_input(X_train.astype("float32"))
X_test_pp  = preprocess_input(X_test.astype("float32"))

# %% [markdown]
# ### Building the VGG19

# %%
vgg_transfer = VGG19(
    include_top=False,
    weights="imagenet",      
    input_shape=(32, 32, 3)
)

vgg_transfer.trainable = False

# %%
vgg_model = Sequential([ 
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),
    
    Lambda(preprocess_input, name="vgg19_preprocess"),

    vgg_transfer,

    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(10, activation="softmax")    
])

vgg_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

vgg_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ ?                           │     0 (unbuilt) │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19_preprocess (Lambda)            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 1, 1, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
vgg_transfer.trainable = True   # Unfreezes

for layer in vgg_model.layers[:-4]:
    layer.trainable = False

vgg_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [raw]
# vgg_history = vgg_model.fit(
#     X_train, y_train_ohe,
#     validation_split=0.1,
#     epochs=5,
#     batch_size=128,
#     callbacks=[early_stop, reduce_lr],
#     verbose=1
# )

# %% [markdown]
# ### Loading the pickle
#
# ##### We had to adjust an incompatibility error for our files

# %%
p = Path("vgg_model.pkl")
data = p.read_bytes()


idx = data.find(b"PK\x03\x04")
print("ZIP header index:", idx)

if idx != -1:
    out = Path("recovered_model.keras")
    out.write_bytes(data[idx:])
    print("Wrote:", out, "size MB:", out.stat().st_size / (1024*1024))

    # Verify zip integrity
    with zipfile.ZipFile(out, "r") as z:
        print("Zip OK. First entries:", z.namelist()[:20])
else:
    print("No embedded zip header found inside the pickle.")
# Out:
# Files in archive (first 30): ['metadata.json', 'config.json', 'model.weights.h5']
# Weight candidates: ['model.weights.h5']
# Extracted weights file: model.weights.h5

# %%
keras_zip = "recovered_model.keras"

with zipfile.ZipFile(keras_zip, "r") as z:
    names = z.namelist()
    print("Files in archive (first 30):", names[:30])

    weight_candidates = [n for n in names if n.endswith(".weights.h5") or "weights" in n.lower() and n.endswith(".h5")]
    print("Weight candidates:", weight_candidates)

    weights_name = weight_candidates[0]
    z.extract(weights_name, ".")

print("Extracted weights file:", weights_name)

# %% [markdown]
# ### Reconstructing the model
#
# #### Lambda was removed we will add it again on the prediction

# %%
vgg_transfer = VGG19(include_top=False
                     ,weights=None
                     ,input_shape=(32, 32, 3)
                    )

vgg_fixed = Sequential([
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),

    # Lambda removed
    vgg_transfer,

    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(10, activation="softmax")
])

# %% [markdown]
# ### Reloading the weights

# %%
dummy = tf.zeros((1, 32, 32, 3), dtype=tf.float32)
_ = vgg_fixed(dummy, training=False)

vgg_fixed.load_weights(weights_name)

# %% [markdown]
# ### Recompiling

# %%
vgg_fixed.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
vgg_fixed.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ (1, 32, 32, 3)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ (1, 32, 32, 3)              │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (1, 1, 1, 512)              │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (1, 512)                    │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (1, 512)                    │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (1, 10)                     │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,029,514 (76.41 MB)
#  Trainable params: 20,029,514 (76.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### We go test accuracy of 82 %, val loss 0.58.

# %%
x = preprocess_input(X_test.astype("float32"))

test_loss, test_acc = vgg_fixed.evaluate(x, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 56s 179ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 56s 176ms/step - accuracy: 0.8315 - loss: 0.5661
# Test accuracy: 0.8271999955177307
# Test loss: 0.585747480392456

# %% [markdown]
# ##### We could hyperparametrize more but we are good

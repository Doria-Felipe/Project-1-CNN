# %% [markdown]
# # Task
#
# #### Build a Convolutional Neural Network (CNN) model to classify images from a given dataset into predefined categories/classes.

# %% [markdown]
# ## The Dataset
#
# #### We could choose between Animals 10 and CIFAR-10; we chose the latter to focus on training our models.
#
# #### - 60,000 32x32 color images in 10 classes
# #### - 6,000 images per class.

# %% [markdown]
# ## Imports

# %%
import os
import pickle
import random
import zipfile
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import SGD, Adam, Adagrad
from tensorflow.keras.metrics import TopKCategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory, to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Activation, RandomFlip, RandomTranslation, Lambda

# %% [markdown]
# ## Setting the random seed
#
# #### This will guarantee near-reproducible results.
#
# #### TensorFlow is not bit-exact deterministic by default, so some tiny numerical differences can occur (~0.1 %-0.3 %).
#
# #### This can escalate exponentially, but the cost for determinism would be slowing down our training using the following import:
#
# #### `from tensorflow.config.experimental import enable_op_determinism`
#
# #### We decided not to use the import.

# %%
seed = 42
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Load CIFAR-10 dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Data Exploration
#
# #### Let's take a look at the shapes of our training and testing data.
#
# #### The second, third, and fourth columns of X will be our input format for the NN.

# %%
print('X_train: ' ,X_train.shape)
print('X_test: ' ,X_test.shape)
print('y_train: ' ,y_train.shape)
print('y_test: ' ,y_test.shape)
# Out:
# X_train:  (50000, 32, 32, 3)
# X_test:  (10000, 32, 32, 3)
# y_train:  (50000, 1)
# y_test:  (10000, 1)

# %% [markdown]
# #### Also, it is good to define our classes as they are presented on the dataset homepage.
#
# #### As we can see below, they are all perfectly balanced.

# %%
class_names = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(class_names[u], c)
# Out:
# airplane 5000
# automobile 5000
# bird 5000
# cat 5000
# deer 5000
# dog 5000
# frog 5000
# horse 5000
# ship 5000
# truck 5000

# %% [markdown]
# ### Check the min max pixel value
#
# #### Just as a sanity check, let's see the min and max of the values, they should be 0 and 255

# %%
print("Min pixel value:", X_train.min())
print("Max pixel value:", X_train.max())
# Out:
# Min pixel value: 0
# Max pixel value: 255

# %% [markdown]
# ## Data Preprocessing
#
# #### Let's make our target y categorical and normalize our X by dividing its value by 255.

# %% [markdown]
# ### OHE y to categorical

# %%
num_classes = 10
y_train_ohe = to_categorical(y_train, num_classes)
y_test_ohe  = to_categorical(y_test,  num_classes)

# %%
print('y_train_ohe: ' ,y_train_ohe.shape)
print('y_test_ohe: ' ,y_test_ohe.shape)
# Out:
# y_train_ohe:  (50000, 10)
# y_test_ohe:  (10000, 10)

# %% [markdown]
# ### Normalize the training and test

# %%
X_train = X_train.astype('float32')/255.0

# %%
X_test = X_test.astype('float32')/255.0

# %% [markdown]
# #### As a sanity check let's see the mean and standard deviation.

# %%
mean_train = X_train.mean(axis=(0,1,2))
std_train  = X_train.std(axis=(0,1,2))

mean_test = X_test.mean(axis=(0,1,2))
std_test  = X_test.std(axis=(0,1,2))


print("Mean:", mean_train)
print("Std:", std_train)
print("Mean:", mean_test)
print("Std:", std_test)
# Out:
# Mean: [0.4914009  0.48215896 0.4465308 ]
# Std: [0.24703279 0.24348423 0.26158753]
# Mean: [0.49421427 0.4851322  0.45040992]
# Std: [0.24665268 0.24289216 0.2615922 ]

# %% [markdown]
# ## Challenger Model 8: Winner!
#
# #### Adding data augmentation, small horizontal flips
#
# #### We achieved 84% test accuracy and 0.47 test loss.

# %%
challenger8 = Sequential([
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),

    Conv2D(64, (3,3), padding="same", activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger8.compile(
    optimizer=SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=2, min_lr=1e-4
)

# %%
challenger8_history = challenger8.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=80,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 149s 404ms/step - accuracy: 0.1631 - loss: 2.1996 - top3_accuracy: 0.4325 - val_accuracy: 0.2650 - val_loss: 1.9134 - val_top3_accuracy: 0.6372 - learning_rate: 0.0500
# Epoch 2/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 155s 439ms/step - accuracy: 0.2665 - loss: 1.8980 - top3_accuracy: 0.6420 - val_accuracy: 0.3862 - val_loss: 1.6068 - val_top3_accuracy: 0.7498 - learning_rate: 0.0500
# Epoch 3/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.3667 - loss: 1.6681 - top3_accuracy: 0.7401 - val_accuracy: 0.4308 - val_loss: 1.4990 - val_top3_accuracy: 0.7866 - learning_rate: 0.0500
# Epoch 4/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 150s 425ms/step - accuracy: 0.4260 - loss: 1.5232 - top3_accuracy: 0.7879 - val_accuracy: 0.5090 - val_loss: 1.3559 - val_top3_accuracy: 0.8344 - learning_rate: 0.0500
# Epoch 5/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 152s 431ms/step - accuracy: 0.4775 - loss: 1.4077 - top3_accuracy: 0.8216 - val_accuracy: 0.5460 - val_loss: 1.2161 - val_top3_accuracy: 0.8540 - learning_rate: 0.0500
# Epoch 6/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 149s 422ms/step - accuracy: 0.5189 - loss: 1.3084 - top3_accuracy: 0.8413 - val_accuracy: 0.5970 - val_loss: 1.1022 - val_top3_accuracy: 0.8870 - learning_rate: 0.0500
# Epoch 7/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 151s 428ms/step - accuracy: 0.5591 - loss: 1.2273 - top3_accuracy: 0.8578 - val_accuracy: 0.6140 - val_loss: 1.0486 - val_top3_accuracy: 0.8976 - learning_rate: 0.0500
# Epoch 8/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 159s 451ms/step - accuracy: 0.5776 - loss: 1.1689 - top3_accuracy: 0.8707 - val_accuracy: 0.6442 - val_loss: 0.9786 - val_top3_accuracy: 0.9084 - learning_rate: 0.0500
# Epoch 9/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 145s 412ms/step - accuracy: 0.6045 - loss: 1.1118 - top3_accuracy: 0.8786 - val_accuracy: 0.6754 - val_loss: 0.9102 - val_top3_accuracy: 0.9212 - learning_rate: 0.0500
# Epoch 10/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 146s 415ms/step - accuracy: 0.6258 - loss: 1.0555 - top3_accuracy: 0.8907 - val_accuracy: 0.6876 - val_loss: 0.8762 - val_top3_accuracy: 0.9226 - learning_rate: 0.0500
# Epoch 11/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 142s 403ms/step - accuracy: 0.6570 - loss: 0.9710 - top3_accuracy: 0.9055 - val_accuracy: 0.7118 - val_loss: 0.8169 - val_top3_accuracy: 0.9298 - learning_rate: 0.0500
# Epoch 13/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 144s 409ms/step - accuracy: 0.6669 - loss: 0.9421 - top3_accuracy: 0.9102 - val_accuracy: 0.7242 - val_loss: 0.7839 - val_top3_accuracy: 0.9388 - learning_rate: 0.0500
# Epoch 14/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 143s 406ms/step - accuracy: 0.6805 - loss: 0.9071 - top3_accuracy: 0.9166 - val_accuracy: 0.7358 - val_loss: 0.7677 - val_top3_accuracy: 0.9424 - learning_rate: 0.0500
# Epoch 15/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 144s 408ms/step - accuracy: 0.6906 - loss: 0.8774 - top3_accuracy: 0.9214 - val_accuracy: 0.7350 - val_loss: 0.7764 - val_top3_accuracy: 0.9418 - learning_rate: 0.0500
# Epoch 16/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 150s 427ms/step - accuracy: 0.7019 - loss: 0.8553 - top3_accuracy: 0.9232 - val_accuracy: 0.7382 - val_loss: 0.7534 - val_top3_accuracy: 0.9420 - learning_rate: 0.0500
# Epoch 17/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 141s 400ms/step - accuracy: 0.7100 - loss: 0.8371 - top3_accuracy: 0.9252 - val_accuracy: 0.7314 - val_loss: 0.7635 - val_top3_accuracy: 0.9408 - learning_rate: 0.0500
# Epoch 18/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 299s 850ms/step - accuracy: 0.7150 - loss: 0.8179 - top3_accuracy: 0.9265 - val_accuracy: 0.7560 - val_loss: 0.6967 - val_top3_accuracy: 0.9420 - learning_rate: 0.0500
# Epoch 19/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 337ms/step - accuracy: 0.7240 - loss: 0.8026 - top3_accuracy: 0.9303 - val_accuracy: 0.7614 - val_loss: 0.6733 - val_top3_accuracy: 0.9498 - learning_rate: 0.0500
# Epoch 20/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 139s 395ms/step - accuracy: 0.7322 - loss: 0.7730 - top3_accuracy: 0.9353 - val_accuracy: 0.7628 - val_loss: 0.6690 - val_top3_accuracy: 0.9480 - learning_rate: 0.0500
# Epoch 21/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 115s 327ms/step - accuracy: 0.7416 - loss: 0.7565 - top3_accuracy: 0.9356 - val_accuracy: 0.7554 - val_loss: 0.6916 - val_top3_accuracy: 0.9510 - learning_rate: 0.0500
# Epoch 22/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 337ms/step - accuracy: 0.7428 - loss: 0.7517 - top3_accuracy: 0.9347 - val_accuracy: 0.7756 - val_loss: 0.6367 - val_top3_accuracy: 0.9492 - learning_rate: 0.0500
# Epoch 23/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 117s 332ms/step - accuracy: 0.7503 - loss: 0.7238 - top3_accuracy: 0.9397 - val_accuracy: 0.7810 - val_loss: 0.6141 - val_top3_accuracy: 0.9542 - learning_rate: 0.0500
# Epoch 24/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 122s 348ms/step - accuracy: 0.7521 - loss: 0.7226 - top3_accuracy: 0.9416 - val_accuracy: 0.7814 - val_loss: 0.6256 - val_top3_accuracy: 0.9528 - learning_rate: 0.0500
# Epoch 25/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.7579 - loss: 0.7020 - top3_accuracy: 0.9435 - val_accuracy: 0.7852 - val_loss: 0.6016 - val_top3_accuracy: 0.9606 - learning_rate: 0.0500
# Epoch 26/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 341ms/step - accuracy: 0.7601 - loss: 0.6914 - top3_accuracy: 0.9463 - val_accuracy: 0.7850 - val_loss: 0.6317 - val_top3_accuracy: 0.9548 - learning_rate: 0.0500
# Epoch 27/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 112s 318ms/step - accuracy: 0.7612 - loss: 0.6935 - top3_accuracy: 0.9437 - val_accuracy: 0.7808 - val_loss: 0.6230 - val_top3_accuracy: 0.9552 - learning_rate: 0.0500
# Epoch 28/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 112s 317ms/step - accuracy: 0.7785 - loss: 0.6432 - top3_accuracy: 0.9512 - val_accuracy: 0.7994 - val_loss: 0.5639 - val_top3_accuracy: 0.9598 - learning_rate: 0.0250
# Epoch 29/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 337ms/step - accuracy: 0.7913 - loss: 0.6073 - top3_accuracy: 0.9558 - val_accuracy: 0.8042 - val_loss: 0.5636 - val_top3_accuracy: 0.9622 - learning_rate: 0.0250
# Epoch 30/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 340ms/step - accuracy: 0.7934 - loss: 0.6040 - top3_accuracy: 0.9561 - val_accuracy: 0.8040 - val_loss: 0.5588 - val_top3_accuracy: 0.9632 - learning_rate: 0.0250
# Epoch 31/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.7984 - loss: 0.5964 - top3_accuracy: 0.9560 - val_accuracy: 0.8072 - val_loss: 0.5558 - val_top3_accuracy: 0.9642 - learning_rate: 0.0250
# Epoch 32/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.7994 - loss: 0.5840 - top3_accuracy: 0.9586 - val_accuracy: 0.8118 - val_loss: 0.5382 - val_top3_accuracy: 0.9660 - learning_rate: 0.0250
# Epoch 33/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 126s 356ms/step - accuracy: 0.8023 - loss: 0.5829 - top3_accuracy: 0.9579 - val_accuracy: 0.8054 - val_loss: 0.5550 - val_top3_accuracy: 0.9632 - learning_rate: 0.0250
# Epoch 34/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 123s 349ms/step - accuracy: 0.8065 - loss: 0.5665 - top3_accuracy: 0.9605 - val_accuracy: 0.8162 - val_loss: 0.5312 - val_top3_accuracy: 0.9638 - learning_rate: 0.0250
# Epoch 35/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 122s 346ms/step - accuracy: 0.8034 - loss: 0.5723 - top3_accuracy: 0.9598 - val_accuracy: 0.8104 - val_loss: 0.5470 - val_top3_accuracy: 0.9666 - learning_rate: 0.0250
# Epoch 36/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.8096 - loss: 0.5584 - top3_accuracy: 0.9602 - val_accuracy: 0.8174 - val_loss: 0.5328 - val_top3_accuracy: 0.9650 - learning_rate: 0.0250
# Epoch 37/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 339ms/step - accuracy: 0.8150 - loss: 0.5410 - top3_accuracy: 0.9622 - val_accuracy: 0.8316 - val_loss: 0.4864 - val_top3_accuracy: 0.9704 - learning_rate: 0.0125
# Epoch 38/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.8203 - loss: 0.5282 - top3_accuracy: 0.9646 - val_accuracy: 0.8246 - val_loss: 0.5075 - val_top3_accuracy: 0.9692 - learning_rate: 0.0125
# Epoch 39/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.8225 - loss: 0.5207 - top3_accuracy: 0.9645 - val_accuracy: 0.8300 - val_loss: 0.4893 - val_top3_accuracy: 0.9714 - learning_rate: 0.0125
# Epoch 40/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 341ms/step - accuracy: 0.8266 - loss: 0.5014 - top3_accuracy: 0.9659 - val_accuracy: 0.8358 - val_loss: 0.4796 - val_top3_accuracy: 0.9712 - learning_rate: 0.0063
# Epoch 41/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 341ms/step - accuracy: 0.8299 - loss: 0.4933 - top3_accuracy: 0.9698 - val_accuracy: 0.8348 - val_loss: 0.4791 - val_top3_accuracy: 0.9716 - learning_rate: 0.0063
# Epoch 42/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.8284 - loss: 0.4981 - top3_accuracy: 0.9663 - val_accuracy: 0.8362 - val_loss: 0.4813 - val_top3_accuracy: 0.9716 - learning_rate: 0.0063
# Epoch 43/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 120s 342ms/step - accuracy: 0.8296 - loss: 0.4923 - top3_accuracy: 0.9675 - val_accuracy: 0.8370 - val_loss: 0.4839 - val_top3_accuracy: 0.9708 - learning_rate: 0.0063
# Epoch 44/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 124s 353ms/step - accuracy: 0.8316 - loss: 0.4855 - top3_accuracy: 0.9687 - val_accuracy: 0.8356 - val_loss: 0.4800 - val_top3_accuracy: 0.9704 - learning_rate: 0.0031
# Epoch 45/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 119s 338ms/step - accuracy: 0.8364 - loss: 0.4793 - top3_accuracy: 0.9693 - val_accuracy: 0.8420 - val_loss: 0.4710 - val_top3_accuracy: 0.9716 - learning_rate: 0.0031
# Epoch 46/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 118s 336ms/step - accuracy: 0.8354 - loss: 0.4830 - top3_accuracy: 0.9694 - val_accuracy: 0.8368 - val_loss: 0.4741 - val_top3_accuracy: 0.9684 - learning_rate: 0.0031
# Epoch 47/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 129s 366ms/step - accuracy: 0.8373 - loss: 0.4767 - top3_accuracy: 0.9702 - val_accuracy: 0.8416 - val_loss: 0.4715 - val_top3_accuracy: 0.9708 - learning_rate: 0.0031
# Epoch 48/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 129s 367ms/step - accuracy: 0.8394 - loss: 0.4737 - top3_accuracy: 0.9694 - val_accuracy: 0.8426 - val_loss: 0.4667 - val_top3_accuracy: 0.9720 - learning_rate: 0.0016
# Epoch 49/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 135s 385ms/step - accuracy: 0.8382 - loss: 0.4717 - top3_accuracy: 0.9692 - val_accuracy: 0.8406 - val_loss: 0.4766 - val_top3_accuracy: 0.9690 - learning_rate: 0.0016
# Epoch 50/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 136s 386ms/step - accuracy: 0.8401 - loss: 0.4693 - top3_accuracy: 0.9696 - val_accuracy: 0.8460 - val_loss: 0.4588 - val_top3_accuracy: 0.9734 - learning_rate: 0.0016
# Epoch 51/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 136s 385ms/step - accuracy: 0.8379 - loss: 0.4751 - top3_accuracy: 0.9695 - val_accuracy: 0.8442 - val_loss: 0.4642 - val_top3_accuracy: 0.9716 - learning_rate: 0.0016
# Epoch 52/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 145s 413ms/step - accuracy: 0.8378 - loss: 0.4702 - top3_accuracy: 0.9708 - val_accuracy: 0.8404 - val_loss: 0.4669 - val_top3_accuracy: 0.9708 - learning_rate: 0.0016
# Epoch 53/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 153s 436ms/step - accuracy: 0.8422 - loss: 0.4633 - top3_accuracy: 0.9704 - val_accuracy: 0.8418 - val_loss: 0.4689 - val_top3_accuracy: 0.9718 - learning_rate: 7.8125e-04
# Epoch 54/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 153s 435ms/step - accuracy: 0.8412 - loss: 0.4628 - top3_accuracy: 0.9712 - val_accuracy: 0.8426 - val_loss: 0.4664 - val_top3_accuracy: 0.9716 - learning_rate: 7.8125e-04
# Epoch 55/80
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 147s 417ms/step - accuracy: 0.8417 - loss: 0.4576 - top3_accuracy: 0.9715 - val_accuracy: 0.8418 - val_loss: 0.4678 - val_top3_accuracy: 0.9716 - learning_rate: 3.9063e-04

# %%
challenger8.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip_2 (RandomFlip)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_2                 │ (None, 32, 32, 3)           │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 555,926 (2.12 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 277,964 (1.06 MB)

# %% [markdown]
# #### We got 84 % as Test accuracy and 0.47 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger8.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)

plt.figure(figsize=(8, 5))
plt.plot(challenger8_history.history['loss'], label='Training Loss')
plt.plot(challenger8_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.8426 - loss: 0.4780 - top3_accuracy: 0.9696
# Test accuracy: 0.8431000113487244
# Test loss: 0.4781797230243683
# Test Top3 accuracy: 0.9702000021934509

# %%
y_pred_proba = challenger8.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving in pickle

# %%
# with open('challenger8.pkl', 'wb') as file:
#     pickle.dump(challenger8, file)

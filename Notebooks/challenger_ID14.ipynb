# %% [markdown]
# # Task
#
# #### Build a Convolutional Neural Network (CNN) model to classify images from a given dataset into predefined categories/classes.

# %% [markdown]
# ## The Dataset
#
# #### We could choose between Animals 10 and CIFAR-10; we chose the latter to focus on training our models.
#
# #### - 60,000 32x32 color images in 10 classes
# #### - 6,000 images per class.

# %% [markdown]
# ## Imports

# %%
import os
import pickle
import random
import zipfile
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import SGD, Adam, Adagrad
from tensorflow.keras.metrics import TopKCategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory, to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Activation, RandomFlip, RandomTranslation, Lambda

# %% [markdown]
# ## Setting the random seed
#
# #### This will guarantee near-reproducible results.
#
# #### TensorFlow is not bit-exact deterministic by default, so some tiny numerical differences can occur (~0.1 %-0.3 %).
#
# #### This can escalate exponentially, but the cost for determinism would be slowing down our training using the following import:
#
# #### `from tensorflow.config.experimental import enable_op_determinism`
#
# #### We decided not to use the import.

# %%
seed = 42
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Load CIFAR-10 dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Data Exploration
#
# #### Let's take a look at the shapes of our training and testing data.
#
# #### The second, third, and fourth columns of X will be our input format for the NN.

# %%
print('X_train: ' ,X_train.shape)
print('X_test: ' ,X_test.shape)
print('y_train: ' ,y_train.shape)
print('y_test: ' ,y_test.shape)
# Out:
# X_train:  (50000, 32, 32, 3)
# X_test:  (10000, 32, 32, 3)
# y_train:  (50000, 1)
# y_test:  (10000, 1)

# %% [markdown]
# #### Also, it is good to define our classes as they are presented on the dataset homepage.
#
# #### As we can see below, they are all perfectly balanced.

# %%
class_names = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(class_names[u], c)
# Out:
# airplane 5000
# automobile 5000
# bird 5000
# cat 5000
# deer 5000
# dog 5000
# frog 5000
# horse 5000
# ship 5000
# truck 5000

# %% [markdown]
# ### Check the min max pixel value
#
# #### Just as a sanity check, let's see the min and max of the values, they should be 0 and 255

# %%
print("Min pixel value:", X_train.min())
print("Max pixel value:", X_train.max())
# Out:
# Min pixel value: 0
# Max pixel value: 255

# %% [markdown]
# ## Data Preprocessing
#
# #### Let's make our target y categorical and normalize our X by dividing its value by 255.

# %% [markdown]
# ### OHE y to categorical

# %%
num_classes = 10
y_train_ohe = to_categorical(y_train, num_classes)
y_test_ohe  = to_categorical(y_test,  num_classes)

# %%
print('y_train_ohe: ' ,y_train_ohe.shape)
print('y_test_ohe: ' ,y_test_ohe.shape)
# Out:
# y_train_ohe:  (50000, 10)
# y_test_ohe:  (10000, 10)

# %% [markdown]
# ### Normalize the training and test

# %%
X_train = X_train.astype('float32')/255.0

# %%
X_test = X_test.astype('float32')/255.0

# %% [markdown]
# #### As a sanity check let's see the mean and standard deviation.

# %%
mean_train = X_train.mean(axis=(0,1,2))
std_train  = X_train.std(axis=(0,1,2))

mean_test = X_test.mean(axis=(0,1,2))
std_test  = X_test.std(axis=(0,1,2))


print("Mean:", mean_train)
print("Std:", std_train)
print("Mean:", mean_test)
print("Std:", std_test)
# Out:
# Mean: [0.4914009  0.48215896 0.4465308 ]
# Std: [0.24703279 0.24348423 0.26158753]
# Mean: [0.49421427 0.4851322  0.45040992]
# Std: [0.24665268 0.24289216 0.2615922 ]

# %% [markdown]
# ## Challenger Model 6:
#
# #### Made the first Conv. block to have 64 N and the second 128.
#
# #### Increased the batch size to 512.
#
# #### We got 77 % as Test accuracy and 0.65 as test loss.

# %%
challenger6 = Sequential([
    Conv2D(64, (3,3), activation="relu", input_shape=(32,32,3)),
    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(10, activation="softmax")
])

challenger6.compile(
    optimizer=SGD(learning_rate=0.05
                  ,momentum=0.9
                  ,nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
challenger6_history = challenger6.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=512,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 92s 989ms/step - accuracy: 0.1248 - loss: 2.2845 - top3_accuracy: 0.3549 - val_accuracy: 0.0980 - val_loss: 2.2961 - val_top3_accuracy: 0.3210
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 941ms/step - accuracy: 0.1241 - loss: 2.2758 - top3_accuracy: 0.3577 - val_accuracy: 0.1742 - val_loss: 2.2297 - val_top3_accuracy: 0.4592
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 932ms/step - accuracy: 0.1675 - loss: 2.1936 - top3_accuracy: 0.4597 - val_accuracy: 0.2204 - val_loss: 2.0540 - val_top3_accuracy: 0.5534
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 963ms/step - accuracy: 0.2101 - loss: 2.0807 - top3_accuracy: 0.5344 - val_accuracy: 0.2358 - val_loss: 2.0037 - val_top3_accuracy: 0.5946
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 945ms/step - accuracy: 0.2253 - loss: 2.0176 - top3_accuracy: 0.5713 - val_accuracy: 0.2736 - val_loss: 1.8899 - val_top3_accuracy: 0.6502
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 954ms/step - accuracy: 0.2593 - loss: 1.9218 - top3_accuracy: 0.6258 - val_accuracy: 0.3242 - val_loss: 1.7858 - val_top3_accuracy: 0.6874
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 942ms/step - accuracy: 0.2906 - loss: 1.8385 - top3_accuracy: 0.6646 - val_accuracy: 0.2626 - val_loss: 2.0477 - val_top3_accuracy: 0.5630
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 959ms/step - accuracy: 0.3161 - loss: 1.7866 - top3_accuracy: 0.6885 - val_accuracy: 0.3706 - val_loss: 1.6771 - val_top3_accuracy: 0.7296
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 944ms/step - accuracy: 0.3666 - loss: 1.6647 - top3_accuracy: 0.7405 - val_accuracy: 0.4188 - val_loss: 1.5242 - val_top3_accuracy: 0.7790
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 913ms/step - accuracy: 0.4031 - loss: 1.5934 - top3_accuracy: 0.7638 - val_accuracy: 0.4360 - val_loss: 1.5102 - val_top3_accuracy: 0.7740
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 931ms/step - accuracy: 0.4256 - loss: 1.5326 - top3_accuracy: 0.7819 - val_accuracy: 0.4644 - val_loss: 1.4613 - val_top3_accuracy: 0.7956
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 969ms/step - accuracy: 0.4492 - loss: 1.4921 - top3_accuracy: 0.7905 - val_accuracy: 0.4694 - val_loss: 1.4231 - val_top3_accuracy: 0.8076
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 971ms/step - accuracy: 0.4767 - loss: 1.4261 - top3_accuracy: 0.8092 - val_accuracy: 0.4920 - val_loss: 1.4041 - val_top3_accuracy: 0.8012
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 86s 980ms/step - accuracy: 0.4893 - loss: 1.4022 - top3_accuracy: 0.8153 - val_accuracy: 0.5276 - val_loss: 1.3009 - val_top3_accuracy: 0.8368
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 939ms/step - accuracy: 0.5153 - loss: 1.3370 - top3_accuracy: 0.8335 - val_accuracy: 0.5422 - val_loss: 1.2529 - val_top3_accuracy: 0.8530
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 898ms/step - accuracy: 0.5305 - loss: 1.2974 - top3_accuracy: 0.8416 - val_accuracy: 0.5406 - val_loss: 1.2244 - val_top3_accuracy: 0.8596
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 908ms/step - accuracy: 0.5497 - loss: 1.2605 - top3_accuracy: 0.8500 - val_accuracy: 0.5934 - val_loss: 1.1267 - val_top3_accuracy: 0.8776
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 952ms/step - accuracy: 0.5657 - loss: 1.2175 - top3_accuracy: 0.8575 - val_accuracy: 0.6080 - val_loss: 1.0856 - val_top3_accuracy: 0.8860
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 990ms/step - accuracy: 0.5817 - loss: 1.1764 - top3_accuracy: 0.8658 - val_accuracy: 0.6108 - val_loss: 1.0840 - val_top3_accuracy: 0.8910
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 948ms/step - accuracy: 0.5911 - loss: 1.1484 - top3_accuracy: 0.8739 - val_accuracy: 0.6280 - val_loss: 1.0327 - val_top3_accuracy: 0.9004
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 952ms/step - accuracy: 0.6116 - loss: 1.1039 - top3_accuracy: 0.8810 - val_accuracy: 0.6462 - val_loss: 0.9817 - val_top3_accuracy: 0.9120
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 86s 977ms/step - accuracy: 0.6224 - loss: 1.0707 - top3_accuracy: 0.8888 - val_accuracy: 0.6532 - val_loss: 0.9592 - val_top3_accuracy: 0.9096
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 987ms/step - accuracy: 0.6350 - loss: 1.0369 - top3_accuracy: 0.8957 - val_accuracy: 0.6698 - val_loss: 0.9212 - val_top3_accuracy: 0.9196
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 934ms/step - accuracy: 0.6433 - loss: 1.0131 - top3_accuracy: 0.9000 - val_accuracy: 0.6682 - val_loss: 0.9154 - val_top3_accuracy: 0.9216
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 965ms/step - accuracy: 0.6474 - loss: 0.9945 - top3_accuracy: 0.9036 - val_accuracy: 0.6904 - val_loss: 0.8616 - val_top3_accuracy: 0.9296
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.6577 - loss: 0.9729 - top3_accuracy: 0.9075 - val_accuracy: 0.6922 - val_loss: 0.8619 - val_top3_accuracy: 0.9290
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.6719 - loss: 0.9351 - top3_accuracy: 0.9129 - val_accuracy: 0.6996 - val_loss: 0.8502 - val_top3_accuracy: 0.9302
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.6781 - loss: 0.9201 - top3_accuracy: 0.9139 - val_accuracy: 0.7082 - val_loss: 0.8295 - val_top3_accuracy: 0.9320
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.6878 - loss: 0.8905 - top3_accuracy: 0.9193 - val_accuracy: 0.7056 - val_loss: 0.8170 - val_top3_accuracy: 0.9336
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6908 - loss: 0.8787 - top3_accuracy: 0.9202 - val_accuracy: 0.7150 - val_loss: 0.8030 - val_top3_accuracy: 0.9356
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.7018 - loss: 0.8534 - top3_accuracy: 0.9250 - val_accuracy: 0.7234 - val_loss: 0.7780 - val_top3_accuracy: 0.9384
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.7032 - loss: 0.8399 - top3_accuracy: 0.9277 - val_accuracy: 0.7214 - val_loss: 0.7777 - val_top3_accuracy: 0.9414
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7125 - loss: 0.8197 - top3_accuracy: 0.9301 - val_accuracy: 0.7338 - val_loss: 0.7452 - val_top3_accuracy: 0.9414
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.7201 - loss: 0.8007 - top3_accuracy: 0.9334 - val_accuracy: 0.7296 - val_loss: 0.7623 - val_top3_accuracy: 0.9424
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.7284 - loss: 0.7829 - top3_accuracy: 0.9341 - val_accuracy: 0.7410 - val_loss: 0.7318 - val_top3_accuracy: 0.9438
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 88s 998ms/step - accuracy: 0.7317 - loss: 0.7691 - top3_accuracy: 0.9369 - val_accuracy: 0.7482 - val_loss: 0.7130 - val_top3_accuracy: 0.9456
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.7403 - loss: 0.7446 - top3_accuracy: 0.9386 - val_accuracy: 0.7522 - val_loss: 0.7086 - val_top3_accuracy: 0.9448
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 944ms/step - accuracy: 0.7479 - loss: 0.7321 - top3_accuracy: 0.9401 - val_accuracy: 0.7554 - val_loss: 0.6965 - val_top3_accuracy: 0.9458
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 935ms/step - accuracy: 0.7511 - loss: 0.7138 - top3_accuracy: 0.9432 - val_accuracy: 0.7530 - val_loss: 0.6968 - val_top3_accuracy: 0.9478
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7566 - loss: 0.7054 - top3_accuracy: 0.9453 - val_accuracy: 0.7644 - val_loss: 0.6804 - val_top3_accuracy: 0.9466
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.7599 - loss: 0.6929 - top3_accuracy: 0.9472 - val_accuracy: 0.7572 - val_loss: 0.6942 - val_top3_accuracy: 0.9480
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.7633 - loss: 0.6757 - top3_accuracy: 0.9495 - val_accuracy: 0.7670 - val_loss: 0.6767 - val_top3_accuracy: 0.9500
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.7733 - loss: 0.6588 - top3_accuracy: 0.9516 - val_accuracy: 0.7722 - val_loss: 0.6727 - val_top3_accuracy: 0.9494
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7740 - loss: 0.6500 - top3_accuracy: 0.9535 - val_accuracy: 0.7676 - val_loss: 0.6631 - val_top3_accuracy: 0.9522
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.7792 - loss: 0.6369 - top3_accuracy: 0.9538 - val_accuracy: 0.7776 - val_loss: 0.6512 - val_top3_accuracy: 0.9538
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.7841 - loss: 0.6138 - top3_accuracy: 0.9554 - val_accuracy: 0.7718 - val_loss: 0.6653 - val_top3_accuracy: 0.9532
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.7880 - loss: 0.6090 - top3_accuracy: 0.9569 - val_accuracy: 0.7712 - val_loss: 0.6640 - val_top3_accuracy: 0.9522
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.7915 - loss: 0.6055 - top3_accuracy: 0.9574 - val_accuracy: 0.7818 - val_loss: 0.6429 - val_top3_accuracy: 0.9526
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7976 - loss: 0.5866 - top3_accuracy: 0.9593 - val_accuracy: 0.7814 - val_loss: 0.6431 - val_top3_accuracy: 0.9562
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.8020 - loss: 0.5724 - top3_accuracy: 0.9624 - val_accuracy: 0.7766 - val_loss: 0.6434 - val_top3_accuracy: 0.9566

# %%
challenger6.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 14, 14, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 14, 14, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 555,926 (2.12 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 277,964 (1.06 MB)

# %% [markdown]
# #### We got 77 % as Test accuracy and 0.65 as test loss.

# %%
test_loss, test_acc, top3_accuracy = challenger6.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)

plt.figure(figsize=(8, 5))
plt.plot(challenger6_history.history['loss'], label='Training Loss')
plt.plot(challenger6_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.7790 - loss: 0.6412 - top3_accuracy: 0.9524
# Test accuracy: 0.7759000062942505
# Test loss: 0.6567584872245789

# %%
print("Test Top3 accuracy:", top3_accuracy)
# Out:
# Test Top3 accuracy: 0.9502000212669373

# %%
y_pred_proba = challenger6.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
with open('challenger6.pkl', 'wb') as file:
    pickle.dump(challenger6, file)

# %%
m.compile(
    optimizer=SGD(learning_rate=0.05, momentum=0.9, nesterov=True),
    loss="categorical_crossentropy",
    metrics=["accuracy", TopKCategoricalAccuracy(k=3, name="top3_accuracy")]
)

# %%
m.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)           │ (1, 32, 32, 3)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_1                 │ (1, 32, 32, 3)              │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (1, 32, 32, 64)             │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (1, 32, 32, 64)             │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (1, 16, 16, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (1, 16, 16, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (1, 16, 16, 128)            │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (1, 16, 16, 128)            │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (1, 8, 8, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (1, 8, 8, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (1, 128)                    │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (1, 128)                    │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (1, 128)                    │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (1, 10)                     │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 277,962 (1.06 MB)
#  Trainable params: 277,962 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
test_loss, test_acc, top3_accuracy = m.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
print("Test Top3 accuracy:", top3_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8426 - loss: 0.4780 - top3_accuracy: 0.9696
# Test accuracy: 0.8431000113487244
# Test loss: 0.4781797230243683
# Test Top3 accuracy: 0.9702000021934509

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

y_train_ohe = to_categorical(y_train, 10)
y_test_ohe  = to_categorical(y_test, 10)

X_train_pp = preprocess_input(X_train.astype("float32"))
X_test_pp  = preprocess_input(X_test.astype("float32"))

# %%
vgg_transfer = VGG19(
    include_top=False,
    weights="imagenet",      
    input_shape=(32, 32, 3)
)

vgg_transfer.trainable = False

# %%
vgg_model = Sequential([ 
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),
    
    Lambda(preprocess_input, name="vgg19_preprocess"),

    vgg_transfer,

    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(10, activation="softmax")    
])

vgg_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

vgg_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ ?                           │     0 (unbuilt) │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19_preprocess (Lambda)            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 1, 1, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ ?                           │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
vgg_transfer.trainable = True   # Unfreezes

for layer in vgg_model.layers[:-4]:
    layer.trainable = False

vgg_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [raw]
# vgg_history = vgg_model.fit(
#     X_train, y_train_ohe,
#     validation_split=0.1,
#     epochs=5,
#     batch_size=128,
#     callbacks=[early_stop, reduce_lr],
#     verbose=1
# )

# %%
p = Path("vgg_model.pkl")
data = p.read_bytes()


idx = data.find(b"PK\x03\x04")
print("ZIP header index:", idx)

if idx != -1:
    out = Path("recovered_model.keras")
    out.write_bytes(data[idx:])
    print("Wrote:", out, "size MB:", out.stat().st_size / (1024*1024))

    # Verify zip integrity
    with zipfile.ZipFile(out, "r") as z:
        print("Zip OK. First entries:", z.namelist()[:20])
else:
    print("No embedded zip header found inside the pickle.")
# Out:
# Files in archive (first 30): ['metadata.json', 'config.json', 'model.weights.h5']
# Weight candidates: ['model.weights.h5']
# Extracted weights file: model.weights.h5

# %%
keras_zip = "recovered_model.keras"

with zipfile.ZipFile(keras_zip, "r") as z:
    names = z.namelist()
    print("Files in archive (first 30):", names[:30])

    weight_candidates = [n for n in names if n.endswith(".weights.h5") or "weights" in n.lower() and n.endswith(".h5")]
    print("Weight candidates:", weight_candidates)

    weights_name = weight_candidates[0]
    z.extract(weights_name, ".")

print("Extracted weights file:", weights_name)

# %%
vgg_transfer = VGG19(include_top=False
                     ,weights=None
                     ,input_shape=(32, 32, 3)
                    )

vgg_fixed = Sequential([
    RandomFlip("horizontal"),
    RandomTranslation(0.1, 0.1),

    # Lambda removed
    vgg_transfer,

    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(10, activation="softmax")
])

# %%
dummy = tf.zeros((1, 32, 32, 3), dtype=tf.float32)
_ = vgg_fixed(dummy, training=False)

vgg_fixed.load_weights(weights_name)

# %%
vgg_fixed.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
vgg_fixed.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ (1, 32, 32, 3)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ (1, 32, 32, 3)              │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (1, 1, 1, 512)              │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (1, 512)                    │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (1, 512)                    │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (1, 10)                     │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,029,514 (76.41 MB)
#  Trainable params: 20,029,514 (76.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### We go test accuracy of 82 %, val loss 0.58.

# %%
x = preprocess_input(X_test.astype("float32"))

test_loss, test_acc = vgg_fixed.evaluate(x, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 56s 179ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 56s 176ms/step - accuracy: 0.8315 - loss: 0.5661
# Test accuracy: 0.8271999955177307
# Test loss: 0.585747480392456

# %% [markdown]
# ##### We could hyperparametrize more but we are good

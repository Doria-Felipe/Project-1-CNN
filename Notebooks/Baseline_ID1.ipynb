# %% [markdown]
# # Task
#
# #### Build a Convolutional Neural Network (CNN) model to classify images from a given dataset into predefined categories/classes.

# %% [markdown]
# ## The Dataset
#
# #### We could choose between Animals 10 and CIFAR-10; we chose the latter to focus on training our models.
#
# #### - 60,000 32x32 color images in 10 classes
# #### - 6,000 images per class.

# %% [markdown]
# ## Imports

# %%
import os
import pickle
import random
import zipfile
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import SGD, Adam, Adagrad
from tensorflow.keras.metrics import TopKCategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory, to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Activation, RandomFlip, RandomTranslation, Lambda

# %% [markdown]
# ## Setting the random seed
#
# #### This will guarantee near-reproducible results.
#
# #### TensorFlow is not bit-exact deterministic by default, so some tiny numerical differences can occur (~0.1 %-0.3 %).
#
# #### This can escalate exponentially, but the cost for determinism would be slowing down our training using the following import:
#
# #### `from tensorflow.config.experimental import enable_op_determinism`
#
# #### We decided not to use the import.

# %%
seed = 42
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Load CIFAR-10 dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Data Exploration
#
# #### Let's take a look at the shapes of our training and testing data.
#
# #### The second, third, and fourth columns of X will be our input format for the NN.

# %%
print('X_train: ' ,X_train.shape)
print('X_test: ' ,X_test.shape)
print('y_train: ' ,y_train.shape)
print('y_test: ' ,y_test.shape)
# Out:
# X_train:  (50000, 32, 32, 3)
# X_test:  (10000, 32, 32, 3)
# y_train:  (50000, 1)
# y_test:  (10000, 1)

# %% [markdown]
# #### Also, it is good to define our classes as they are presented on the dataset homepage.
#
# #### As we can see below, they are all perfectly balanced.

# %%
class_names = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(class_names[u], c)
# Out:
# airplane 5000
# automobile 5000
# bird 5000
# cat 5000
# deer 5000
# dog 5000
# frog 5000
# horse 5000
# ship 5000
# truck 5000

# %% [markdown]
# ### Check the min max pixel value
#
# #### Just as a sanity check, let's see the min and max of the values, they should be 0 and 255

# %%
print("Min pixel value:", X_train.min())
print("Max pixel value:", X_train.max())
# Out:
# Min pixel value: 0
# Max pixel value: 255

# %% [markdown]
# ## Data Preprocessing
#
# #### Let's make our target y categorical and normalize our X by dividing its value by 255.

# %% [markdown]
# ### OHE y to categorical

# %%
num_classes = 10
y_train_ohe = to_categorical(y_train, num_classes)
y_test_ohe  = to_categorical(y_test,  num_classes)

# %%
print('y_train_ohe: ' ,y_train_ohe.shape)
print('y_test_ohe: ' ,y_test_ohe.shape)
# Out:
# y_train_ohe:  (50000, 10)
# y_test_ohe:  (10000, 10)

# %% [markdown]
# ### Normalize the training and test

# %%
X_train = X_train.astype('float32')/255.0

# %%
X_test = X_test.astype('float32')/255.0

# %% [markdown]
# #### As a sanity check let's see the mean and standard deviation.

# %%
mean_train = X_train.mean(axis=(0,1,2))
std_train  = X_train.std(axis=(0,1,2))

mean_test = X_test.mean(axis=(0,1,2))
std_test  = X_test.std(axis=(0,1,2))


print("Mean:", mean_train)
print("Std:", std_train)
print("Mean:", mean_test)
print("Std:", std_test)
# Out:
# Mean: [0.4914009  0.48215896 0.4465308 ]
# Std: [0.24703279 0.24348423 0.26158753]
# Mean: [0.49421427 0.4851322  0.45040992]
# Std: [0.24665268 0.24289216 0.2615922 ]

# %% [markdown]
# ## Baseline model
#
# #### We will now create a baseline model with 1 Conv. Layer with 32 N, 1 Dense Layer with 100 N, and the output Dense Layer with softmax.
#
# #### Adam optimizer, categorical cross-entropy as the loss function, and accuracy as the metric were chosen.
#
# #### Added the early stop function.
#
# #### We got 62% as Test accuracy and 1.12 as test loss.

# %%
model = Sequential([
                    Conv2D(32, (3, 3), activation='relu', input_shape=(32,32,3))
                    ,MaxPooling2D(pool_size=(2, 2))
                    ,Flatten()
                    ,Dense(100, activation='relu')
                    ,Dense(10, activation='softmax')
                    ])
# Out:
# C:\Users\felip\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(X_train,
                    y_train_ohe, 
                    validation_split=0.1, 
                    epochs= 50, 
                    batch_size=128, 
                    verbose=1)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.3484 - loss: 1.8075 - val_accuracy: 0.5436 - val_loss: 1.3342
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.5509 - loss: 1.2748 - val_accuracy: 0.5738 - val_loss: 1.2320
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.5989 - loss: 1.1613 - val_accuracy: 0.6088 - val_loss: 1.1277
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.6325 - loss: 1.0651 - val_accuracy: 0.6240 - val_loss: 1.0850
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6560 - loss: 0.9951 - val_accuracy: 0.6120 - val_loss: 1.1155
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6691 - loss: 0.9546 - val_accuracy: 0.6314 - val_loss: 1.0615
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6899 - loss: 0.8991 - val_accuracy: 0.6408 - val_loss: 1.0559
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7086 - loss: 0.8446 - val_accuracy: 0.6422 - val_loss: 1.0475
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7235 - loss: 0.8065 - val_accuracy: 0.6488 - val_loss: 1.0229
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7364 - loss: 0.7696 - val_accuracy: 0.6714 - val_loss: 0.9840
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7505 - loss: 0.7331 - val_accuracy: 0.6670 - val_loss: 0.9870
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.7622 - loss: 0.6898 - val_accuracy: 0.6626 - val_loss: 1.0169
# Epoch 13/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7782 - loss: 0.6507 - val_accuracy: 0.6566 - val_loss: 1.0357
# Epoch 14/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7884 - loss: 0.6206 - val_accuracy: 0.6774 - val_loss: 1.0063
# Epoch 15/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.8019 - loss: 0.5889 - val_accuracy: 0.6740 - val_loss: 1.0082
# Epoch 16/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.8056 - loss: 0.5690 - val_accuracy: 0.6688 - val_loss: 1.0321
# Epoch 17/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.8180 - loss: 0.5337 - val_accuracy: 0.6608 - val_loss: 1.0726
# Epoch 18/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.8338 - loss: 0.4953 - val_accuracy: 0.6396 - val_loss: 1.1624
# Epoch 19/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.8396 - loss: 0.4849 - val_accuracy: 0.6486 - val_loss: 1.1835
# Epoch 20/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.8477 - loss: 0.4573 - val_accuracy: 0.6642 - val_loss: 1.1252
# Epoch 21/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.8649 - loss: 0.4162 - val_accuracy: 0.6638 - val_loss: 1.1540
# Epoch 22/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.8711 - loss: 0.3922 - val_accuracy: 0.6582 - val_loss: 1.1986
# Epoch 23/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.8795 - loss: 0.3676 - val_accuracy: 0.6576 - val_loss: 1.1986
# Epoch 24/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.8888 - loss: 0.3427 - val_accuracy: 0.6576 - val_loss: 1.2193
# Epoch 25/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.8996 - loss: 0.3174 - val_accuracy: 0.6570 - val_loss: 1.2854
# Epoch 26/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9063 - loss: 0.2958 - val_accuracy: 0.6362 - val_loss: 1.3230
# Epoch 27/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9148 - loss: 0.2745 - val_accuracy: 0.6526 - val_loss: 1.3471
# Epoch 28/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9260 - loss: 0.2496 - val_accuracy: 0.6462 - val_loss: 1.3993
# Epoch 29/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9263 - loss: 0.2388 - val_accuracy: 0.6542 - val_loss: 1.4415
# Epoch 30/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9299 - loss: 0.2285 - val_accuracy: 0.6324 - val_loss: 1.5205
# Epoch 31/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9339 - loss: 0.2184 - val_accuracy: 0.6498 - val_loss: 1.5208
# Epoch 32/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.9428 - loss: 0.1938 - val_accuracy: 0.6444 - val_loss: 1.5803
# Epoch 33/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9498 - loss: 0.1752 - val_accuracy: 0.6372 - val_loss: 1.6413
# Epoch 34/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9521 - loss: 0.1679 - val_accuracy: 0.6412 - val_loss: 1.6754
# Epoch 35/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9619 - loss: 0.1452 - val_accuracy: 0.6472 - val_loss: 1.6770
# Epoch 36/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9664 - loss: 0.1305 - val_accuracy: 0.6402 - val_loss: 1.7681
# Epoch 37/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.9644 - loss: 0.1314 - val_accuracy: 0.6346 - val_loss: 1.8446
# Epoch 38/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9650 - loss: 0.1258 - val_accuracy: 0.6308 - val_loss: 1.9120
# Epoch 39/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9717 - loss: 0.1071 - val_accuracy: 0.6370 - val_loss: 1.9737
# Epoch 40/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9742 - loss: 0.1010 - val_accuracy: 0.6290 - val_loss: 2.0218
# Epoch 41/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9722 - loss: 0.1017 - val_accuracy: 0.6384 - val_loss: 1.9966
# Epoch 42/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9811 - loss: 0.0809 - val_accuracy: 0.6372 - val_loss: 2.0825
# Epoch 43/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9783 - loss: 0.0830 - val_accuracy: 0.6302 - val_loss: 2.1273
# Epoch 44/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.9852 - loss: 0.0672 - val_accuracy: 0.6262 - val_loss: 2.2278
# Epoch 45/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.9754 - loss: 0.0869 - val_accuracy: 0.6364 - val_loss: 2.2606
# Epoch 46/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9853 - loss: 0.0636 - val_accuracy: 0.6274 - val_loss: 2.3044
# Epoch 47/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9825 - loss: 0.0681 - val_accuracy: 0.6246 - val_loss: 2.3752
# Epoch 48/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.9842 - loss: 0.0634 - val_accuracy: 0.6268 - val_loss: 2.4040
# Epoch 49/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9887 - loss: 0.0544 - val_accuracy: 0.6202 - val_loss: 2.5213
# Epoch 50/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9838 - loss: 0.0623 - val_accuracy: 0.6278 - val_loss: 2.5406

# %% [markdown]
# #### We got 61 % as Test accuracy and 2.64 as test loss.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6089 - loss: 2.6343
# Test accuracy: 0.6148999929428101
# Test loss: 2.646989583969116

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_pred_proba = model.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Add early stopping
#
# #### We decided to add early stopping after observing better epochs before the end.

# %%
clear_session()

# %%
model = Sequential([
                    Conv2D(32, (3, 3), activation='relu', input_shape=(32,32,3))
                    ,MaxPooling2D(pool_size=(2, 2))
                    ,Flatten()
                    ,Dense(100, activation='relu')
                    ,Dense(10, activation='softmax')
                    ])

model.compile(
    optimizer='adam',
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train, y_train_ohe,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.3383 - loss: 1.8319 - val_accuracy: 0.5068 - val_loss: 1.4042
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.5282 - loss: 1.3345 - val_accuracy: 0.5642 - val_loss: 1.2486
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5782 - loss: 1.2016 - val_accuracy: 0.5816 - val_loss: 1.1792
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6112 - loss: 1.1149 - val_accuracy: 0.6018 - val_loss: 1.1412
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6365 - loss: 1.0473 - val_accuracy: 0.6056 - val_loss: 1.1324
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6541 - loss: 0.9927 - val_accuracy: 0.6130 - val_loss: 1.1213
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.6706 - loss: 0.9438 - val_accuracy: 0.6224 - val_loss: 1.1032
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6877 - loss: 0.9001 - val_accuracy: 0.6260 - val_loss: 1.0988
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7040 - loss: 0.8594 - val_accuracy: 0.6240 - val_loss: 1.0950
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.7185 - loss: 0.8217 - val_accuracy: 0.6298 - val_loss: 1.0921
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7290 - loss: 0.7871 - val_accuracy: 0.6256 - val_loss: 1.1182
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7402 - loss: 0.7600 - val_accuracy: 0.6256 - val_loss: 1.1357
# Epoch 13/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7476 - loss: 0.7392 - val_accuracy: 0.6350 - val_loss: 1.1281
# Epoch 14/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7557 - loss: 0.7153 - val_accuracy: 0.6462 - val_loss: 1.1044
# Epoch 15/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7648 - loss: 0.6866 - val_accuracy: 0.6518 - val_loss: 1.0932

# %% [markdown]
# #### We got 62% as Test accuracy and 1.12 as test loss.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test_ohe , verbose=1)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Categorical Cross-Entropy')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6187 - loss: 1.1092
# Test accuracy: 0.6244999766349792
# Test loss: 1.1270169019699097

# %%
y_pred_proba = model.predict(X_test, batch_size=128, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test_ohe, axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("CIFAR-10 Confusion Matrix (Test Set)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
